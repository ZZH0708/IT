# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import random
from copy import deepcopy
import networkx as nx
from matplotlib.lines import Line2D
import imageio
from PIL import Image, ImageDraw, ImageFont

# ==================== 可调参数区域 ====================
# 网络结构参数
NETWORK_CONFIG = {
    'INPUT_SIZE': 8,       # 输入层维度(LunarLander观测空间)
    'HIDDEN_SIZE': 64,     # 隐藏层神经元数(建议范围:16-256)
    'OUTPUT_SIZE': 4,      # 输出层维度(LunarLander动作空间)

    # 训练参数
    'POP_SIZE': 50,        # 种群大小(建议范围:30-100)
    'GENERATIONS': 300,    # 训练代数(建议范围:200-1000)
    'EPISODES_PER_NETWORK': 3,  # 每个网络评估次数

    # 进化参数
    'MUTATION_RATE': 0.3,  # 变异率(建议范围:0.1-0.5)
    'ELITE_RATIO': 0.2,    # 精英保留比例
    'WEIGHT_MUTATION_STRENGTH': 0.05,  # 权重变异强度
    'BIAS_MUTATION_STRENGTH': 0.05,    # 偏置变异强度
    'OUTPUT_MUTATION_STRENGTH': 0.02   # 输出层变异强度
}

# 可视化设置
VISUALIZATION_CONFIG = {
    'SAVE_NETWORK_VIZ': True,    # 是否保存网络可视化
    'RECORD_BEST_EPISODE': True, # 是否录制最佳个体表现
    'VIZ_GENERATIONS': [0, 150, 299]  # 在哪些代进行可视化
}

# ==================== 核心代码 ====================
# 定义激活函数
def relu(x):
    return np.maximum(0, x)

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

class NeuronGenome:
    def __init__(self, input_size):
        self.weights = np.random.randn(input_size) * 0.1
        self.bias = np.random.randn() * 0.1

    def mutate(self):
        if np.random.rand() < NETWORK_CONFIG['MUTATION_RATE']:
            self.weights += np.random.randn(*self.weights.shape) * NETWORK_CONFIG['WEIGHT_MUTATION_STRENGTH']
            self.bias += np.random.randn() * NETWORK_CONFIG['BIAS_MUTATION_STRENGTH']

    def copy(self):
        copied = NeuronGenome(len(self.weights))
        copied.weights = np.copy(self.weights)
        copied.bias = self.bias
        return copied

class ESPNetwork:
    def __init__(self, hidden_neurons):
        self.hidden_neurons = hidden_neurons
        self.output_weights = np.random.randn(
            len(hidden_neurons),
            NETWORK_CONFIG['OUTPUT_SIZE']
        ) * 0.1

    def forward(self, x):
        h = np.array([np.dot(n.weights, x) + n.bias for n in self.hidden_neurons])
        h = relu(h)
        return softmax(np.dot(h, self.output_weights))

def evaluate(network, env_name="LunarLander-v3", render=False):
    """评估网络性能并返回平均奖励"""
    env = gym.make(env_name, render_mode="rgb_array" if render else None)
    total_reward = 0

    for _ in range(NETWORK_CONFIG['EPISODES_PER_NETWORK']):
        obs, _ = env.reset()
        done = False
        episode_reward = 0

        while not done:
            action_probs = network.forward(obs)
            action = np.argmax(action_probs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_reward += reward

        total_reward += episode_reward

    env.close()
    return total_reward / NETWORK_CONFIG['EPISODES_PER_NETWORK']

def run_evolution():
    """主训练函数"""
    # 初始化种群
    subpops = [
        [NeuronGenome(NETWORK_CONFIG['INPUT_SIZE'])
        for _ in range(NETWORK_CONFIG['POP_SIZE'])
    ] for _ in range(NETWORK_CONFIG['HIDDEN_SIZE'])]

    output_weight_pool = [
        np.random.randn(NETWORK_CONFIG['HIDDEN_SIZE'], NETWORK_CONFIG['OUTPUT_SIZE']) * 0.1
        for _ in range(NETWORK_CONFIG['POP_SIZE'])
    ]

    best_scores = []
    best_network = None
    global_best_score = -np.inf

    # 创建输出目录
    os.makedirs("results/network_viz", exist_ok=True)
    os.makedirs("results/episodes", exist_ok=True)

    for gen in range(NETWORK_CONFIG['GENERATIONS']):
        # 评估种群
        fitnesses = []
        networks = []

        for _ in range(NETWORK_CONFIG['POP_SIZE']):
            # 从每个子种群随机选择神经元
            hidden_indices = [random.randint(0, NETWORK_CONFIG['POP_SIZE']-1)
                            for _ in range(NETWORK_CONFIG['HIDDEN_SIZE'])]
            hidden_neurons = [subpops[i][idx] for i, idx in enumerate(hidden_indices)]

            # 创建网络并评估
            network = ESPNetwork(hidden_neurons)
            network.output_weights = output_weight_pool[random.randint(0, NETWORK_CONFIG['POP_SIZE']-1)]
            reward = evaluate(network)

            fitnesses.append(reward)
            networks.append((network, hidden_indices))

            # 更新全局最佳
            if reward > global_best_score:
                global_best_score = reward
                best_network = deepcopy(network)

        # 进化过程
        elite_count = int(NETWORK_CONFIG['POP_SIZE'] * NETWORK_CONFIG['ELITE_RATIO'])

        # 更新隐藏神经元
        for i in range(NETWORK_CONFIG['HIDDEN_SIZE']):
            # 按适应度排序
            indices = list(range(NETWORK_CONFIG['POP_SIZE']))
            random.shuffle(indices)  # 添加随机性

            # 选择精英
            elites = sorted(zip(fitnesses, subpops[i]),
                          key=lambda x: x[0],
                          reverse=True)[:elite_count]
            elites = [ind.copy() for (_, ind) in elites]

            # 生成新一代
            new_pop = elites[:]
            while len(new_pop) < NETWORK_CONFIG['POP_SIZE']:
                parent = random.choice(elites)
                offspring = parent.copy()
                offspring.mutate()
                new_pop.append(offspring)

            subpops[i] = new_pop

        # 更新输出权重
        elite_indices = np.argsort(fitnesses)[-elite_count:]
        elite_outputs = [output_weight_pool[i] for i in elite_indices]

        new_outputs = [w.copy() for w in elite_outputs]
        while len(new_outputs) < NETWORK_CONFIG['POP_SIZE']:
            base = random.choice(elite_outputs)
            mutated = base + np.random.randn(*base.shape) * NETWORK_CONFIG['OUTPUT_MUTATION_STRENGTH']
            new_outputs.append(mutated)

        output_weight_pool = new_outputs

        # 记录结果
        avg_score = np.mean(fitnesses)
        best_scores.append(avg_score)

        print(f"Gen {gen+1}/{NETWORK_CONFIG['GENERATIONS']} | "
              f"Avg: {avg_score:.2f} | Best: {max(fitnesses):.2f} | "
              f"Global Best: {global_best_score:.2f}")

        # 可视化
        if VISUALIZATION_CONFIG['SAVE_NETWORK_VIZ'] and gen in VISUALIZATION_CONFIG['VIZ_GENERATIONS']:
            visualize_network(
                [subpops[i][0] for i in range(NETWORK_CONFIG['HIDDEN_SIZE'])],  # 取每个子种群第一个个体
                output_weight_pool[0],  # 取第一个输出权重
                gen+1,
                filename=f"results/network_viz/gen_{gen+1}.png"
            )

    # 保存最佳个体表现
    if VISUALIZATION_CONFIG['RECORD_BEST_EPISODE'] and best_network:
        record_episode(best_network, "results/episodes/best_episode.gif")

    return subpops, output_weight_pool, best_scores

# ==================== 辅助函数 ====================
def visualize_network(hidden_neurons, output_weights, generation, filename=None):
    """可视化网络结构"""
    plt.figure(figsize=(15, 10))
    G = nx.DiGraph()

    # 添加节点和边(代码略，同前)
    # ...

    if filename:
        plt.savefig(filename, bbox_inches='tight')
    plt.close()

def record_episode(network, filename):
    """录制最佳个体表现"""
    env = gym.make("LunarLander-v3", render_mode="rgb_array")
    obs, _ = env.reset()
    frames = []
    done = False

    while not done:
        frame = env.render()
        img = Image.fromarray(frame)
        # 添加文本标注
        draw = ImageDraw.Draw(img)
        try:
            font = ImageFont.truetype("arial.ttf", 20)
        except:
            font = ImageFont.load_default()
        draw.text((10, 10), "Best Performance", font=font, fill=(255, 255, 255))
        frames.append(img)

        action_probs = network.forward(obs)
        action = np.argmax(action_probs)
        obs, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

    env.close()

    # 保存GIF
    frames[0].save(
        filename,
        save_all=True,
        append_images=frames[1:],
        duration=50,
        loop=0,
        optimize=True,
        quality=20
    )

def plot_results(scores):
    """绘制训练曲线"""
    plt.figure(figsize=(10, 6))
    plt.plot(scores)
    plt.xlabel("Generation")
    plt.ylabel("Average Reward")
    plt.title("Training Progress")
    plt.grid(True)
    plt.savefig("results/training_curve.png", bbox_inches='tight')
    plt.show()

# ==================== 主程序 ====================
if __name__ == '__main__':
    # 安装必要依赖
    try:
        import Box2D
    except ImportError:
        print("Installing dependencies...")
        import subprocess
        subprocess.run(["pip", "install", "swig"])
        subprocess.run(["pip", "install", "gymnasium[box2d]"])

    # 运行进化算法
    subpops, output_weights, scores = run_evolution()

    # 保存模型和结果
    with open("results/esp_model.pkl", "wb") as f:
        pickle.dump({
            'subpops': subpops,
            'output_weights': output_weights,
            'scores': scores,
            'config': NETWORK_CONFIG
        }, f)

    # 绘制训练曲线
    plot_results(scores)
# Out:
# Installing dependencies...
# Gen 1/300 | Avg: -465.01 | Best: -111.09 | Global Best: -111.09
# Gen 2/300 | Avg: -494.12 | Best: -92.91 | Global Best: -92.91
# Gen 3/300 | Avg: -426.11 | Best: -92.33 | Global Best: -92.33
# Gen 4/300 | Avg: -467.03 | Best: -104.74 | Global Best: -92.33
# Gen 5/300 | Avg: -422.41 | Best: -82.24 | Global Best: -82.24
# Gen 6/300 | Avg: -346.52 | Best: -97.84 | Global Best: -82.24
# Gen 7/300 | Avg: -420.09 | Best: -102.00 | Global Best: -82.24
# Gen 8/300 | Avg: -372.05 | Best: -90.24 | Global Best: -82.24
# Gen 9/300 | Avg: -396.10 | Best: -74.34 | Global Best: -74.34
# Gen 10/300 | Avg: -414.13 | Best: -105.63 | Global Best: -74.34
# Gen 11/300 | Avg: -399.93 | Best: -115.07 | Global Best: -74.34
# Gen 12/300 | Avg: -396.01 | Best: -117.93 | Global Best: -74.34
# Gen 13/300 | Avg: -445.53 | Best: -130.94 | Global Best: -74.34
# Gen 14/300 | Avg: -409.63 | Best: -34.15 | Global Best: -34.15
# Gen 15/300 | Avg: -382.24 | Best: -82.53 | Global Best: -34.15
# Gen 16/300 | Avg: -394.48 | Best: -115.32 | Global Best: -34.15
# Gen 17/300 | Avg: -429.18 | Best: -78.59 | Global Best: -34.15
# Gen 18/300 | Avg: -409.67 | Best: -100.96 | Global Best: -34.15
# Gen 19/300 | Avg: -491.60 | Best: -125.64 | Global Best: -34.15
# Gen 20/300 | Avg: -472.96 | Best: -131.81 | Global Best: -34.15
# Gen 21/300 | Avg: -472.11 | Best: -110.48 | Global Best: -34.15
# Gen 22/300 | Avg: -411.24 | Best: -120.99 | Global Best: -34.15
# Gen 23/300 | Avg: -499.10 | Best: -124.29 | Global Best: -34.15
# Gen 24/300 | Avg: -402.32 | Best: -113.33 | Global Best: -34.15
# Gen 25/300 | Avg: -314.31 | Best: -92.19 | Global Best: -34.15
# Gen 26/300 | Avg: -390.30 | Best: -34.43 | Global Best: -34.15
# Gen 27/300 | Avg: -350.75 | Best: -94.72 | Global Best: -34.15
# Gen 28/300 | Avg: -398.51 | Best: -107.86 | Global Best: -34.15
# Gen 29/300 | Avg: -438.37 | Best: -100.65 | Global Best: -34.15
# Gen 30/300 | Avg: -486.52 | Best: -128.52 | Global Best: -34.15
# Gen 31/300 | Avg: -494.93 | Best: -137.41 | Global Best: -34.15
# Gen 32/300 | Avg: -546.67 | Best: -229.66 | Global Best: -34.15
# Gen 33/300 | Avg: -456.41 | Best: -117.27 | Global Best: -34.15
# Gen 34/300 | Avg: -474.71 | Best: -126.98 | Global Best: -34.15
# Gen 35/300 | Avg: -521.90 | Best: -39.85 | Global Best: -34.15
# Gen 36/300 | Avg: -453.05 | Best: -103.11 | Global Best: -34.15
# Gen 37/300 | Avg: -501.98 | Best: -146.73 | Global Best: -34.15
# Gen 38/300 | Avg: -490.04 | Best: -122.48 | Global Best: -34.15
# Gen 39/300 | Avg: -507.94 | Best: -135.11 | Global Best: -34.15
# Gen 40/300 | Avg: -440.81 | Best: -122.64 | Global Best: -34.15
# Gen 41/300 | Avg: -465.93 | Best: -131.68 | Global Best: -34.15
# Gen 42/300 | Avg: -455.74 | Best: -132.23 | Global Best: -34.15
# Gen 43/300 | Avg: -440.14 | Best: -130.12 | Global Best: -34.15
# Gen 44/300 | Avg: -491.21 | Best: -120.43 | Global Best: -34.15
# Gen 45/300 | Avg: -420.74 | Best: -142.75 | Global Best: -34.15
# Gen 46/300 | Avg: -502.16 | Best: -112.06 | Global Best: -34.15
# Gen 47/300 | Avg: -485.24 | Best: -128.32 | Global Best: -34.15
# Gen 48/300 | Avg: -438.51 | Best: -129.38 | Global Best: -34.15
# Gen 49/300 | Avg: -414.42 | Best: -74.15 | Global Best: -34.15
# Gen 50/300 | Avg: -452.00 | Best: -98.67 | Global Best: -34.15
# Gen 51/300 | Avg: -472.74 | Best: -97.18 | Global Best: -34.15
# Gen 52/300 | Avg: -452.28 | Best: -129.77 | Global Best: -34.15
# Gen 53/300 | Avg: -446.84 | Best: -135.96 | Global Best: -34.15
# Gen 54/300 | Avg: -506.51 | Best: -101.81 | Global Best: -34.15
# Gen 55/300 | Avg: -454.74 | Best: -89.34 | Global Best: -34.15
# Gen 56/300 | Avg: -501.44 | Best: -136.21 | Global Best: -34.15
# Gen 57/300 | Avg: -457.22 | Best: -96.23 | Global Best: -34.15
# Gen 58/300 | Avg: -532.27 | Best: -250.85 | Global Best: -34.15
# Gen 59/300 | Avg: -538.99 | Best: -162.35 | Global Best: -34.15
# Gen 60/300 | Avg: -543.08 | Best: -321.02 | Global Best: -34.15
# Gen 61/300 | Avg: -580.77 | Best: -328.04 | Global Best: -34.15
# Gen 62/300 | Avg: -552.52 | Best: -208.62 | Global Best: -34.15
# Gen 63/300 | Avg: -534.94 | Best: -100.83 | Global Best: -34.15
# Gen 64/300 | Avg: -494.39 | Best: -65.22 | Global Best: -34.15
# Gen 65/300 | Avg: -485.85 | Best: -163.60 | Global Best: -34.15
# Gen 66/300 | Avg: -505.81 | Best: -235.25 | Global Best: -34.15
# Gen 67/300 | Avg: -471.37 | Best: -145.60 | Global Best: -34.15
# Gen 68/300 | Avg: -463.45 | Best: -126.35 | Global Best: -34.15
# Gen 69/300 | Avg: -382.21 | Best: -165.73 | Global Best: -34.15
# Gen 70/300 | Avg: -348.31 | Best: -131.71 | Global Best: -34.15
# Gen 71/300 | Avg: -325.99 | Best: -109.05 | Global Best: -34.15
# Gen 72/300 | Avg: -342.74 | Best: -103.99 | Global Best: -34.15
# Gen 73/300 | Avg: -296.64 | Best: -63.35 | Global Best: -34.15
# Gen 74/300 | Avg: -287.44 | Best: -83.02 | Global Best: -34.15
# Gen 75/300 | Avg: -297.32 | Best: -113.61 | Global Best: -34.15
# Gen 76/300 | Avg: -293.27 | Best: -94.36 | Global Best: -34.15
# Gen 77/300 | Avg: -298.51 | Best: -136.82 | Global Best: -34.15
# Gen 78/300 | Avg: -258.97 | Best: -82.30 | Global Best: -34.15
# Gen 79/300 | Avg: -219.94 | Best: -80.64 | Global Best: -34.15
# Gen 80/300 | Avg: -249.86 | Best: -116.11 | Global Best: -34.15
# Gen 81/300 | Avg: -247.01 | Best: -99.77 | Global Best: -34.15
# Gen 82/300 | Avg: -255.37 | Best: -114.66 | Global Best: -34.15
# Gen 83/300 | Avg: -205.39 | Best: -80.82 | Global Best: -34.15
# Gen 84/300 | Avg: -210.53 | Best: -62.92 | Global Best: -34.15
# Gen 85/300 | Avg: -200.26 | Best: -92.13 | Global Best: -34.15
# Gen 86/300 | Avg: -227.52 | Best: -83.72 | Global Best: -34.15
# Gen 87/300 | Avg: -201.95 | Best: -112.92 | Global Best: -34.15
# Gen 88/300 | Avg: -191.68 | Best: -87.22 | Global Best: -34.15
# Gen 89/300 | Avg: -198.08 | Best: -94.07 | Global Best: -34.15
# Gen 90/300 | Avg: -210.57 | Best: -60.71 | Global Best: -34.15
# Gen 91/300 | Avg: -202.23 | Best: -104.27 | Global Best: -34.15
# Gen 92/300 | Avg: -197.78 | Best: -84.19 | Global Best: -34.15
# Gen 93/300 | Avg: -196.04 | Best: -61.75 | Global Best: -34.15
# Gen 94/300 | Avg: -183.56 | Best: -87.88 | Global Best: -34.15
# Gen 95/300 | Avg: -162.60 | Best: -77.53 | Global Best: -34.15
# Gen 96/300 | Avg: -187.18 | Best: -75.05 | Global Best: -34.15
# Gen 97/300 | Avg: -173.85 | Best: -65.32 | Global Best: -34.15
# Gen 98/300 | Avg: -186.94 | Best: -111.85 | Global Best: -34.15
# Gen 99/300 | Avg: -178.51 | Best: -85.62 | Global Best: -34.15
# Gen 100/300 | Avg: -183.78 | Best: -70.89 | Global Best: -34.15
# Gen 101/300 | Avg: -187.19 | Best: -76.38 | Global Best: -34.15
# Gen 102/300 | Avg: -181.04 | Best: -36.95 | Global Best: -34.15
# Gen 103/300 | Avg: -195.55 | Best: -81.18 | Global Best: -34.15
# Gen 104/300 | Avg: -183.83 | Best: -101.81 | Global Best: -34.15
# Gen 105/300 | Avg: -213.03 | Best: -82.32 | Global Best: -34.15
# Gen 106/300 | Avg: -250.87 | Best: -97.38 | Global Best: -34.15
# Gen 107/300 | Avg: -276.24 | Best: -91.42 | Global Best: -34.15
# Gen 108/300 | Avg: -227.82 | Best: -53.86 | Global Best: -34.15
# Gen 109/300 | Avg: -238.18 | Best: -82.16 | Global Best: -34.15
# Gen 110/300 | Avg: -271.81 | Best: -126.10 | Global Best: -34.15
# Gen 111/300 | Avg: -218.05 | Best: -43.81 | Global Best: -34.15
# Gen 112/300 | Avg: -280.70 | Best: -145.85 | Global Best: -34.15
# Gen 113/300 | Avg: -277.47 | Best: -66.86 | Global Best: -34.15
# Gen 114/300 | Avg: -301.89 | Best: -114.87 | Global Best: -34.15
# Gen 115/300 | Avg: -256.12 | Best: -106.24 | Global Best: -34.15
# Gen 116/300 | Avg: -293.20 | Best: -97.78 | Global Best: -34.15
# Gen 117/300 | Avg: -301.28 | Best: -121.59 | Global Best: -34.15
# Gen 118/300 | Avg: -328.67 | Best: -91.55 | Global Best: -34.15
# Gen 119/300 | Avg: -368.86 | Best: -181.69 | Global Best: -34.15
# Gen 120/300 | Avg: -354.34 | Best: -149.97 | Global Best: -34.15
# Gen 121/300 | Avg: -345.42 | Best: -104.06 | Global Best: -34.15
# Gen 122/300 | Avg: -308.98 | Best: -127.34 | Global Best: -34.15
# Gen 123/300 | Avg: -323.91 | Best: -124.35 | Global Best: -34.15
# Gen 124/300 | Avg: -311.39 | Best: -114.19 | Global Best: -34.15
# Gen 125/300 | Avg: -300.34 | Best: -122.37 | Global Best: -34.15
# Gen 126/300 | Avg: -319.17 | Best: -159.55 | Global Best: -34.15
# Gen 127/300 | Avg: -295.87 | Best: -131.36 | Global Best: -34.15
# Gen 128/300 | Avg: -224.22 | Best: -45.62 | Global Best: -34.15
# Gen 129/300 | Avg: -314.15 | Best: -59.90 | Global Best: -34.15
# Gen 130/300 | Avg: -321.70 | Best: -90.22 | Global Best: -34.15
# Gen 131/300 | Avg: -327.78 | Best: -141.92 | Global Best: -34.15
# Gen 132/300 | Avg: -342.35 | Best: -140.47 | Global Best: -34.15
# Gen 133/300 | Avg: -324.45 | Best: -51.16 | Global Best: -34.15
# Gen 134/300 | Avg: -330.37 | Best: -126.26 | Global Best: -34.15
# Gen 135/300 | Avg: -302.58 | Best: -99.80 | Global Best: -34.15
# Gen 136/300 | Avg: -313.91 | Best: -119.19 | Global Best: -34.15
# Gen 137/300 | Avg: -260.93 | Best: -65.64 | Global Best: -34.15
# Gen 138/300 | Avg: -304.21 | Best: -99.55 | Global Best: -34.15
# Gen 139/300 | Avg: -280.42 | Best: -104.72 | Global Best: -34.15
# Gen 140/300 | Avg: -247.27 | Best: -48.40 | Global Best: -34.15
# Gen 141/300 | Avg: -241.58 | Best: -98.61 | Global Best: -34.15
# Gen 142/300 | Avg: -248.90 | Best: -92.73 | Global Best: -34.15
# Gen 143/300 | Avg: -219.16 | Best: -70.50 | Global Best: -34.15
# Gen 144/300 | Avg: -222.32 | Best: -99.88 | Global Best: -34.15
# Gen 145/300 | Avg: -153.69 | Best: -76.88 | Global Best: -34.15
# Gen 146/300 | Avg: -151.02 | Best: -72.34 | Global Best: -34.15
# Gen 147/300 | Avg: -204.07 | Best: -53.25 | Global Best: -34.15
# Gen 148/300 | Avg: -269.89 | Best: -106.54 | Global Best: -34.15
# Gen 149/300 | Avg: -212.86 | Best: -95.04 | Global Best: -34.15
# Gen 150/300 | Avg: -223.16 | Best: -61.88 | Global Best: -34.15
# Gen 151/300 | Avg: -221.00 | Best: -74.59 | Global Best: -34.15
# Gen 152/300 | Avg: -291.71 | Best: -105.28 | Global Best: -34.15
# Gen 153/300 | Avg: -333.08 | Best: -126.48 | Global Best: -34.15
# Gen 154/300 | Avg: -326.95 | Best: -147.50 | Global Best: -34.15
# Gen 155/300 | Avg: -319.51 | Best: -94.06 | Global Best: -34.15
# Gen 156/300 | Avg: -335.50 | Best: -88.50 | Global Best: -34.15
# Gen 157/300 | Avg: -273.91 | Best: -85.01 | Global Best: -34.15
# Gen 158/300 | Avg: -269.34 | Best: -83.87 | Global Best: -34.15
# Gen 159/300 | Avg: -240.40 | Best: -30.81 | Global Best: -30.81
# Gen 160/300 | Avg: -275.43 | Best: -95.02 | Global Best: -30.81
# Gen 161/300 | Avg: -298.31 | Best: -82.47 | Global Best: -30.81
# Gen 162/300 | Avg: -334.10 | Best: -118.96 | Global Best: -30.81
# Gen 163/300 | Avg: -410.75 | Best: -47.56 | Global Best: -30.81
# Gen 164/300 | Avg: -262.24 | Best: -68.27 | Global Best: -30.81
# Gen 165/300 | Avg: -325.81 | Best: -11.70 | Global Best: -11.70
# Gen 166/300 | Avg: -250.22 | Best: -86.15 | Global Best: -11.70
# Gen 167/300 | Avg: -339.59 | Best: -103.99 | Global Best: -11.70
# Gen 168/300 | Avg: -437.88 | Best: -116.12 | Global Best: -11.70
# Gen 169/300 | Avg: -428.59 | Best: -90.48 | Global Best: -11.70
# Gen 170/300 | Avg: -547.68 | Best: -102.16 | Global Best: -11.70
# Gen 171/300 | Avg: -455.23 | Best: -80.78 | Global Best: -11.70
# Gen 172/300 | Avg: -416.55 | Best: -151.20 | Global Best: -11.70
# Gen 173/300 | Avg: -559.95 | Best: -130.30 | Global Best: -11.70
# Gen 174/300 | Avg: -595.26 | Best: -140.93 | Global Best: -11.70
# Gen 175/300 | Avg: -586.31 | Best: -138.82 | Global Best: -11.70
# Gen 176/300 | Avg: -570.43 | Best: -87.89 | Global Best: -11.70
# Gen 177/300 | Avg: -533.84 | Best: -136.32 | Global Best: -11.70
# Gen 178/300 | Avg: -449.95 | Best: -51.27 | Global Best: -11.70
# Gen 179/300 | Avg: -435.87 | Best: -71.52 | Global Best: -11.70
# Gen 180/300 | Avg: -500.66 | Best: -89.58 | Global Best: -11.70
# Gen 181/300 | Avg: -465.96 | Best: -100.59 | Global Best: -11.70
# Gen 182/300 | Avg: -568.85 | Best: -162.56 | Global Best: -11.70
# Gen 183/300 | Avg: -662.14 | Best: -239.69 | Global Best: -11.70
# Gen 184/300 | Avg: -628.83 | Best: -359.73 | Global Best: -11.70
# Gen 185/300 | Avg: -597.83 | Best: -382.00 | Global Best: -11.70
# Gen 186/300 | Avg: -605.83 | Best: -383.83 | Global Best: -11.70
# Gen 187/300 | Avg: -594.15 | Best: -263.84 | Global Best: -11.70
# Gen 188/300 | Avg: -624.70 | Best: -253.07 | Global Best: -11.70
# Gen 189/300 | Avg: -677.98 | Best: -293.33 | Global Best: -11.70
# Gen 190/300 | Avg: -767.08 | Best: -410.42 | Global Best: -11.70
# Gen 191/300 | Avg: -732.72 | Best: -475.04 | Global Best: -11.70
# Gen 192/300 | Avg: -790.11 | Best: -425.79 | Global Best: -11.70
# Gen 193/300 | Avg: -726.86 | Best: -418.87 | Global Best: -11.70
# Gen 194/300 | Avg: -851.20 | Best: -452.79 | Global Best: -11.70
# Gen 195/300 | Avg: -697.44 | Best: -450.72 | Global Best: -11.70
# Gen 196/300 | Avg: -820.89 | Best: -456.67 | Global Best: -11.70
# Gen 197/300 | Avg: -684.50 | Best: -408.12 | Global Best: -11.70
# Gen 198/300 | Avg: -744.93 | Best: -358.21 | Global Best: -11.70
# Gen 199/300 | Avg: -736.54 | Best: -269.13 | Global Best: -11.70
# Gen 200/300 | Avg: -819.03 | Best: -433.03 | Global Best: -11.70
# Gen 201/300 | Avg: -942.41 | Best: -447.80 | Global Best: -11.70
# Gen 202/300 | Avg: -838.41 | Best: -396.89 | Global Best: -11.70
# Gen 203/300 | Avg: -932.49 | Best: -423.93 | Global Best: -11.70
# Gen 204/300 | Avg: -1222.11 | Best: -513.41 | Global Best: -11.70
# Gen 205/300 | Avg: -1110.76 | Best: -560.33 | Global Best: -11.70
# Gen 206/300 | Avg: -965.80 | Best: -411.34 | Global Best: -11.70
# Gen 207/300 | Avg: -1068.73 | Best: -451.07 | Global Best: -11.70
# Gen 208/300 | Avg: -927.84 | Best: -397.82 | Global Best: -11.70
# Gen 209/300 | Avg: -1072.47 | Best: -436.92 | Global Best: -11.70
# Gen 210/300 | Avg: -1019.79 | Best: -460.81 | Global Best: -11.70
# Gen 211/300 | Avg: -951.10 | Best: -451.98 | Global Best: -11.70
# Gen 212/300 | Avg: -971.62 | Best: -354.34 | Global Best: -11.70
# Gen 213/300 | Avg: -769.49 | Best: -435.13 | Global Best: -11.70
# Gen 214/300 | Avg: -887.97 | Best: -427.59 | Global Best: -11.70
# Gen 215/300 | Avg: -823.98 | Best: -405.74 | Global Best: -11.70
# Gen 216/300 | Avg: -815.79 | Best: -419.84 | Global Best: -11.70
# Gen 217/300 | Avg: -816.68 | Best: -403.65 | Global Best: -11.70
# Gen 218/300 | Avg: -744.83 | Best: -392.90 | Global Best: -11.70
# Gen 219/300 | Avg: -762.91 | Best: -468.91 | Global Best: -11.70
# Gen 220/300 | Avg: -788.11 | Best: -426.45 | Global Best: -11.70
# Gen 221/300 | Avg: -834.66 | Best: -407.91 | Global Best: -11.70
# Gen 222/300 | Avg: -917.76 | Best: -487.01 | Global Best: -11.70
# Gen 223/300 | Avg: -925.59 | Best: -427.98 | Global Best: -11.70
# Gen 224/300 | Avg: -933.67 | Best: -382.56 | Global Best: -11.70
# Gen 225/300 | Avg: -910.06 | Best: -447.88 | Global Best: -11.70
# Gen 226/300 | Avg: -901.51 | Best: -321.14 | Global Best: -11.70
# Gen 227/300 | Avg: -813.71 | Best: -364.36 | Global Best: -11.70
# Gen 228/300 | Avg: -829.74 | Best: -441.03 | Global Best: -11.70
# Gen 229/300 | Avg: -855.41 | Best: -332.98 | Global Best: -11.70
# Gen 230/300 | Avg: -788.30 | Best: -345.01 | Global Best: -11.70
# Gen 231/300 | Avg: -781.18 | Best: -440.05 | Global Best: -11.70
# Gen 232/300 | Avg: -791.11 | Best: -437.47 | Global Best: -11.70
# Gen 233/300 | Avg: -778.28 | Best: -372.82 | Global Best: -11.70
# Gen 234/300 | Avg: -727.81 | Best: -240.98 | Global Best: -11.70
# Gen 235/300 | Avg: -699.91 | Best: -325.51 | Global Best: -11.70
# Gen 236/300 | Avg: -736.00 | Best: -465.02 | Global Best: -11.70
# Gen 237/300 | Avg: -713.54 | Best: -377.96 | Global Best: -11.70
# Gen 238/300 | Avg: -733.63 | Best: -331.51 | Global Best: -11.70
# Gen 239/300 | Avg: -721.56 | Best: -367.62 | Global Best: -11.70
# Gen 240/300 | Avg: -710.63 | Best: -336.76 | Global Best: -11.70
# Gen 241/300 | Avg: -715.96 | Best: -346.83 | Global Best: -11.70
# Gen 242/300 | Avg: -734.28 | Best: -362.38 | Global Best: -11.70
# Gen 243/300 | Avg: -675.45 | Best: -310.52 | Global Best: -11.70
# Gen 244/300 | Avg: -763.37 | Best: -416.35 | Global Best: -11.70
# Gen 245/300 | Avg: -786.95 | Best: -474.07 | Global Best: -11.70
# Gen 246/300 | Avg: -872.72 | Best: -452.28 | Global Best: -11.70
# Gen 247/300 | Avg: -855.73 | Best: -523.54 | Global Best: -11.70
# Gen 248/300 | Avg: -785.66 | Best: -469.18 | Global Best: -11.70
# Gen 249/300 | Avg: -783.29 | Best: -474.82 | Global Best: -11.70
# Gen 250/300 | Avg: -816.95 | Best: -506.84 | Global Best: -11.70
# Gen 251/300 | Avg: -826.36 | Best: -459.97 | Global Best: -11.70
# Gen 252/300 | Avg: -866.07 | Best: -492.63 | Global Best: -11.70
# Gen 253/300 | Avg: -906.90 | Best: -506.58 | Global Best: -11.70
# Gen 254/300 | Avg: -884.91 | Best: -470.12 | Global Best: -11.70
# Gen 255/300 | Avg: -861.61 | Best: -555.05 | Global Best: -11.70
# Gen 256/300 | Avg: -827.98 | Best: -487.78 | Global Best: -11.70
# Gen 257/300 | Avg: -786.97 | Best: -409.01 | Global Best: -11.70
# Gen 258/300 | Avg: -798.44 | Best: -459.59 | Global Best: -11.70
# Gen 259/300 | Avg: -774.86 | Best: -477.59 | Global Best: -11.70
# Gen 260/300 | Avg: -812.05 | Best: -440.28 | Global Best: -11.70
# Gen 261/300 | Avg: -778.04 | Best: -468.23 | Global Best: -11.70
# Gen 262/300 | Avg: -836.37 | Best: -496.58 | Global Best: -11.70
# Gen 263/300 | Avg: -829.68 | Best: -465.53 | Global Best: -11.70
# Gen 264/300 | Avg: -771.37 | Best: -497.35 | Global Best: -11.70
# Gen 265/300 | Avg: -759.85 | Best: -498.30 | Global Best: -11.70
# Gen 266/300 | Avg: -863.92 | Best: -464.19 | Global Best: -11.70
# Gen 267/300 | Avg: -801.72 | Best: -504.85 | Global Best: -11.70
# Gen 268/300 | Avg: -762.86 | Best: -394.75 | Global Best: -11.70
# Gen 269/300 | Avg: -866.07 | Best: -408.10 | Global Best: -11.70
# Gen 270/300 | Avg: -758.13 | Best: -432.58 | Global Best: -11.70
# Gen 271/300 | Avg: -814.84 | Best: -480.93 | Global Best: -11.70
# Gen 272/300 | Avg: -733.25 | Best: -449.34 | Global Best: -11.70
# Gen 273/300 | Avg: -802.65 | Best: -483.31 | Global Best: -11.70
# Gen 274/300 | Avg: -752.30 | Best: -396.57 | Global Best: -11.70
# Gen 275/300 | Avg: -795.52 | Best: -479.71 | Global Best: -11.70
# Gen 276/300 | Avg: -824.65 | Best: -478.24 | Global Best: -11.70
# Gen 277/300 | Avg: -766.56 | Best: -421.95 | Global Best: -11.70
# Gen 278/300 | Avg: -781.33 | Best: -477.07 | Global Best: -11.70
# Gen 279/300 | Avg: -819.18 | Best: -334.09 | Global Best: -11.70
# Gen 280/300 | Avg: -866.70 | Best: -442.31 | Global Best: -11.70
# Gen 281/300 | Avg: -848.90 | Best: -463.01 | Global Best: -11.70
# Gen 282/300 | Avg: -779.91 | Best: -512.62 | Global Best: -11.70
# Gen 283/300 | Avg: -778.31 | Best: -457.61 | Global Best: -11.70
# Gen 284/300 | Avg: -773.48 | Best: -468.04 | Global Best: -11.70
# Gen 285/300 | Avg: -818.79 | Best: -482.49 | Global Best: -11.70
# Gen 286/300 | Avg: -792.45 | Best: -400.57 | Global Best: -11.70
# Gen 287/300 | Avg: -863.69 | Best: -509.46 | Global Best: -11.70
# Gen 288/300 | Avg: -848.74 | Best: -468.84 | Global Best: -11.70
# Gen 289/300 | Avg: -835.78 | Best: -463.30 | Global Best: -11.70
# Gen 290/300 | Avg: -789.38 | Best: -458.63 | Global Best: -11.70
# Gen 291/300 | Avg: -813.24 | Best: -513.88 | Global Best: -11.70
# Gen 292/300 | Avg: -781.66 | Best: -484.41 | Global Best: -11.70
# Gen 293/300 | Avg: -718.12 | Best: -493.87 | Global Best: -11.70
# Gen 294/300 | Avg: -795.20 | Best: -514.37 | Global Best: -11.70
# Gen 295/300 | Avg: -738.03 | Best: -472.71 | Global Best: -11.70
# Gen 296/300 | Avg: -769.58 | Best: -401.76 | Global Best: -11.70
# Gen 297/300 | Avg: -792.91 | Best: -421.04 | Global Best: -11.70
# Gen 298/300 | Avg: -844.76 | Best: -484.56 | Global Best: -11.70
# Gen 299/300 | Avg: -941.75 | Best: -552.01 | Global Best: -11.70
# Gen 300/300 | Avg: -770.41 | Best: -315.57 | Global Best: -11.70
